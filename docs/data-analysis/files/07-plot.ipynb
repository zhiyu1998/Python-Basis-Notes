# %% [markdown]
# ## PLOT

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

# %%
data = pd.Series(np.random.randn(1000), index=np.arange(1000))
data
# Out:
# 0      2.209695
# 1      2.174834
# 2      0.616076
# 3      0.759948
# 4      2.188458
#          ...
# 995    1.016089
# 996    1.866790
# 997    1.225485
# 998    0.065012
# 999    0.936024
# Length: 1000, dtype: float64

# %%
data = data.cumsum()
data
# Out:
# 0       2.209695
# 1       4.384530
# 2       5.000606
# 3       5.760554
# 4       7.949012
#          ...
# 995     9.806509
# 996    11.673299
# 997    12.898784
# 998    12.963796
# 999    13.899820
# Length: 1000, dtype: float64

# %%
data.plot()
plt.show()

# %%
data = pd.DataFrame(np.random.randn(1000, 4), index=np.arange(1000), columns=list('ABCD'))
data.head()
# Out:
#           A         B         C         D
# 0 -1.404401 -1.361617  0.794683  0.672637
# 1 -0.060662 -0.212794 -1.198357  0.622721
# 2  0.546791  0.717719  1.448742 -0.759707
# 3  0.256927  0.486394  0.015539  0.467752
# 4 -0.217870 -1.108871 -1.541466  1.469205

# %%
data = data.cumsum()
data.head()
# Out:
#           A         B         C         D
# 0 -1.404401 -1.361617  0.794683  0.672637
# 1 -1.465063 -1.574410 -0.403674  1.295357
# 2 -0.918272 -0.856691  1.045068  0.535651
# 3 -0.661345 -0.370296  1.060607  1.003403
# 4 -0.879215 -1.479167 -0.480859  2.472608

# %%
# data.plot()
ax = data.plot.scatter(x='A', y='B', color='DarkBlue', label='Class 1')
data.plot.scatter(x='A', y='C', color='DarkGreen', label='Class 2', ax=ax)
plt.show()
